# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.1-70b-versatile"
)
response = llm.invoke("Prime minister of India:")
print(response.content)
# Out:
# The Prime Minister of India is Narendra Modi.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.adidas-group.com/adidas/job/Spartanburg-Tech-Consultant-SC/1124281801/?feedId=301201&utm_source=j2w")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Tech Consultant Job Details | adidas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     By continuing to use and navigate this website, you are agreeing to the use of cookies.
#
#
#
#                 Accept
#
#                 Close
#
#
#
#
# Press Tab to Move to Skip to Content Link
# Skip to main content
#
#
#
#
#
#
#
#
# Prepare for interview
# Search Jobs
# SEE CATEGORIES
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search by Keyword
#
#
#
#
# Search by Location
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Prepare for interview
# Search Jobs
# SEE CATEGORIES
#
#
#
#
#
#
#
#
#
# View Profile
#
#
#
#
# Employee Login
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search by Keyword
#
#
#
#
# Search by Location
#
#
#
#
#
#
# Show More Options
#
#
#
#
#
# Loading...
#
#
#
#
#
#
#
#                                             Team:
#
#
#
# All
#
#
#
#
#
#                                             Location
#
#
#
# All
#
#
#
#
#
#                                             Type:
#
#
#
# All
#
#
#
#
#
#                                             Grade:
#
#
#
# All
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Create Alert
#
#
#
#
# ×
#
#
# Select how often (in days) to receive an alert:
#
#
#
#
#
#
#
#
#
#
# Start
#
#
#
#
#
#
#
#
#
# Please wait...
#
#
#
#
#
#
#
#
#
#
#
#
#
# Apply now »
#
#
#
#
#
#
#
#
#
#
#
#
# Tech Consultant
#
#
#
#
#
#
#
#
#
#
#
# Purpose & Overall Relevance for the Organization:
# The role of the Technology Consultant is responsible for the planning, installing and for the configuration of software solutions and systems. It is capable to support employees with specific applications and provides expert advisory. The role analyzes information systems of adidas and individualizes specific system solutions to meet the demand of the business.
#
# Key Responsibilities:
# Business analysis
#
# Investigates operational needs and problems, and opportunities, contributing to the recommendation of improvements in automated and non-automated components of new or changed processes and organization.
# Assists in defining acceptance tests for these recommendations.
#
# Requirements definition and management
#
# Defines and manages scoping, requirements definition and prioritization activities for small- scale changes and assists with more complex change initiatives.
# Follows agreed standards, applying appropriate techniques to elicit and document detailed requirements.
# Provides constructive challenge to stakeholders as required.
# Prioritizes requirements and documents traceability to source.
# Reviews requirements for errors and omissions.
# Provides input to the requirements baseline.
# Investigates, manages, and applies authorized requests for changes to base-lined requirements, in line with change management policy.
#
# Porting/software configuration
#
# Assist in the configuration of software and equipment and the systems testing of platform- specific versions of one or more software products.
# Documents faults, implements resolutions and retests to agreed standards.
#
# Application support
#
# Identifies and resolves issues with applications, following agreed procedures.
# Uses application management software and tools to collect agreed performance statistics.
# Carries out agreed applications maintenance tasks.
#
# Key Relationships:
#
# Global IT
# Project implementation teams (Project Managers, Solution Architects, D & A, Platform Engineering, Tech Core, External Tech Consultants)
# DC Local and regional IT teams
# Strategic vendors (Global) – Manhattan, WCS and Vendors for development
# HR Management
# Controlling
#
#
# Knowledge Skills and Abilities:
#
# Experience with building large scale enterprise applications using any programming language, preferably Java/J2EE or Python
# Expert level knowledge of UI/UX design and development using any of the frameworks, preferably Angular, React, Vue JS and TypeScript
# Experience with Manhattan’s WMS (Warehouse Management System) or other supply chain execution systems is a plus. Experience with Java and the Manhattan “Platform” architecture will be an added qualification for this role but is not mandatory.
# Experience in writing complex SQL queries and Stored procedures, fine tune them in any major relational databases, preferably in Oracle
# Expertise in design and development of CI/CD processes using Jenkins pipelines, Ansible automation
# Good knowledge of application performance tuning and refactoring
# Ability to multi-task in a flexible environment & patience to work under pressure.
# Experience in design and development of Cloud native applications and micro services using Kubernetes, docker, AWS, GCP etc. will be a plus.
# Strong understanding of application security, SSL, Encryption, authentication/authorization using Azure AD, openID, SAML etc,
# Expected travel is 20% or less (International if needed).
#
#
# Requisite Education and Experience / Minimum Qualifications:
#
# Four-year college or university degree with focus on Business Administration or IT or related areas, or equivalent combination of education and experience
# Proficient spoken and written command of English
# At least 5-year experience in IT
# 2 years of experience in relevant area
# 1 year of experience in team management
# Understanding of different culture
# Participated in projects with people from other functions/markets
#
#
#
# *Diversity, Equity, and Inclusion at adidas means championing individual uniqueness and cultivating a culture of belonging in which everyone can create at their best.  We embrace diverse backgrounds, experiences, and perspectives and seek to create a workforce that reflects our consumers and communities.
# adidas offers robust and progressive medical, including HSA (Health Savings Account) with employer funding or FSA (Flexible Spending Account) options, dental, vision, prescription drug coverage, adoption, with surrogate and fertility support, short and long-term disability, and basic life and AD&D insurance, which can be supplemented with employee-paid coverage. Employees are able to enroll in adidas’ 401k plan and Stock Purchase Plan with employer match. *Full-time employees are eligible for education assistance and generous Leave policies including 14 weeks of paid parental leave.
# *Employees are eligible to earn an annual bonus based on both company and personal performance. Employees accrue prorated flexible time off in the amount .4388 hours per day that increases with years of service, eleven paid holidays throughout the calendar year and Service Time Off during milestone years.
# *We officially returned to office in a hybrid work environment, working 3 days in office and 2 days remote.The working location of this position is Spartanburg, SC
# *Though our teammates hail from all corners of the world, our working language is English
#
#
#
#
#
#
#
#
# AT ADIDAS WE HAVE A WINNING CULTURE. BUT TO WIN, PHYSICAL POWER IS NOT ENOUGH. JUST LIKE ATHLETES OUR EMPLOYEES NEED MENTAL STRENGTH IN THEIR GAME. WE FOSTER THE ATHLETE’S MINDSET THROUGH A SET OF BEHAVIORS THAT WE WANT TO ENABLE AND DEVELOP IN OUR PEOPLE AND THAT ARE AT THE CORE OF OUR UNIQUE COMPANY CULTURE: THIS IS HOW WE WIN WHILE PLAYING FAIR.
#
# COURAGE: Speak up when you see an opportunity; step up when you see a need..
# OWNERSHIP: Pick up the ball. Be proactive, take responsibility and follow-through.
# INNOVATION: Elevate to win. Be curious, test and learn new and better ways of doing things.
# TEAMPLAY: Win together. Work collaboratively and cultivate a shared mindset.
# INTEGRITY: Play by the rules. Hold yourself and others accountable to our company’s standards.
# RESPECT: Value all players. Display empathy, be inclusive and show dignity to all.
#
#
#
#
#
# adidas celebrates diversity, supports inclusiveness and encourages individual expression in our workplace. We do not tolerate the harassment or discrimination toward any of our applicants or employees. We are an Equal Opportunity Employer.
#
#
#
#
#
#
#
#
#
#
# Job Title:
#
# Tech Consultant
#
#
#
#
#
#
#
#
#
#
# Brand:
#
# adidas
#
#
#
#
#
#
#
#
#
# Location:
#
# Spartanburg
#
#
#
#
#
#
#
#
#
# TEAM:
#
# Information Technology
#
#
#
#
#
#
#
#
#
# State:
#
# SC
#
#
#
#
#
#
#
#
#
# Country/Region:
#
# US
#
#
#
#
#
#
#
#
#
# Contract Type:
#
# Full time
#
#
#
#
#
#
#
#
#
# Number:
#
# 515530
#
#
#
#
#
#
#
#
#
# Date:
#
# Oct 23, 2024
#
#
#
#
#
#
#
#
#
# Apply now »
#
#
#
#
#
#
# Find similar jobs:
#
# Information Technology
#
#
#
#
#
#
#
#
#
#
# Home
# Search Jobs
# See Categories
# Imprint
# Legal Notice
# Privacy Notice
# Contact
# How to apply (français)
#
#
#
#
#
#
# THROUGH SPORT, WE HAVE THE POWER TO CHANGE LIVES. © 2020 adidas. All Rights Reserved.

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
print(res.content)
# Out:
# [
#   {
#     "role": "Tech Consultant",
#     "experience": "At least 5-year experience in IT, 2 years of experience in relevant area, 1 year of experience in team management",
#     "skills": [
#       "Java/J2EE or Python",
#       "UI/UX design and development using Angular, React, Vue JS and TypeScript",
#       "Manhattan’s WMS (Warehouse Management System) or other supply chain execution systems",
#       "SQL queries and Stored procedures in Oracle",
#       "CI/CD processes using Jenkins pipelines, Ansible automation",
#       "Cloud native applications and micro services using Kubernetes, docker, AWS, GCP",
#       "Application security, SSL, Encryption, authentication/authorization using Azure AD, openID, SAML"
#     ],
#     "description": "The role of the Technology Consultant is responsible for the planning, installing and for the configuration of software solutions and systems. It is capable to support employees with specific applications and provides expert advisory. The role analyzes information systems of adidas and individualizes specific system solutions to meet the demand of the business."
#   }
# ]

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Tech Consultant',
#   'experience': 'At least 5-year experience in IT, 2 years of experience in relevant area, 1 year of experience in team management',
#   'skills': ['Java/J2EE or Python',
#    'UI/UX design and development using Angular, React, Vue JS and TypeScript',
#    'Manhattan’s WMS (Warehouse Management System) or other supply chain execution systems',
#    'SQL queries and Stored procedures in Oracle',
#    'CI/CD processes using Jenkins pipelines, Ansible automation',
#    'Cloud native applications and micro services using Kubernetes, docker, AWS, GCP',
#    'Application security, SSL, Encryption, authentication/authorization using Azure AD, openID, SAML'],
#   'description': 'The role of the Technology Consultant is responsible for the planning, installing and for the configuration of software solutions and systems. It is capable to support employees with specific applications and provides expert advisory. The role analyzes information systems of adidas and individualizes specific system solutions to meet the demand of the business.'}]

# %%
type(json_res)
# Out:
# list

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      89 try:
# ---> 90     return func(self, *args, **kwargs)
#      91 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:213, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     212     validate_record_set_for_embedding(record_set=add_records)
# --> 213     add_embeddings = self._embed_record_set(record_set=add_records)
#     214 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:526, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields)
#     525         else:
# --> 526             return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     527 raise ValueError(
#     528     "Record does not contain any non-None fields that can be embedded."
#     529     f"Embeddable Fields: {embeddable_fields}"
#     530     f"Record Fields: {record_set}"
#     531 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:539, in CollectionCommon._embed(self, input)
#     535     raise ValueError(
#     536         "You must provide an embedding function to compute embeddings."
#     537         "https://docs.trychroma.com/guides/embeddings"
#     538     )
# --> 539 return self._embedding_function(input=input)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\types.py:460, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     459 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 460     result = call(self, input)
#     461     assert result is not None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:199, in ONNXMiniLM_L6_V2.__call__(self, input)
#     197 def __call__(self, input: Documents) -> Embeddings:
#     198     # Only download the model when it is actually used
# --> 199     self._download_model_if_not_exists()
#     200     return cast(Embeddings, self._forward(input))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:234, in ONNXMiniLM_L6_V2._download_model_if_not_exists(self)
#     230 with tarfile.open(
#     231     name=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     232     mode="r:gz",
#     233 ) as tar:
# --> 234     tar.extractall(path=self.DOWNLOAD_PATH)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2302, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2301         directories.append(tarinfo)
# -> 2302     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2303                       numeric_owner=numeric_owner)
#    2305 # Reverse sort directories.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2369, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2368 except OSError as e:
# -> 2369     self._handle_fatal_error(e)
#    2370 except ExtractError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2365, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2364 try:
# -> 2365     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2366                          set_attrs=set_attrs,
#    2367                          numeric_owner=numeric_owner)
#    2368 except OSError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2448, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner)
#    2447 if tarinfo.isreg():
# -> 2448     self.makefile(tarinfo, targetpath)
#    2449 elif tarinfo.isdir():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2494, in TarFile.makefile(self, tarinfo, targetpath)
#    2493 bufsize = self.copybufsize
# -> 2494 with bltn_open(targetpath, "wb") as target:
#    2495     if tarinfo.sparse is not None:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\ideapad\\.cache\\chroma\\onnx_models\\all-MiniLM-L6-v2\\onnx\\tokenizer_config.json'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[25], line 9
#       7 if not collection.count():
#       8     for _, row in df.iterrows():
# ----> 9         collection.add(documents=row["Techstack"],
#      10                        metadatas={"links": row["Links"]},
#      11                        ids=[str(uuid.uuid4())])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\Collection.py:81, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      46 def add(
#      47     self,
#      48     ids: OneOrMany[ID],
#    (...)
#      58     uris: Optional[OneOrMany[URI]] = None,
#      59 ) -> None:
#      60     """Add embeddings to the data store.
#      61     Args:
#      62         ids: The ids of the embeddings you wish to add
#    (...)
#      78
#      79     """
# ---> 81     add_request = self._validate_and_prepare_add_request(
#      82         ids=ids,
#      83         embeddings=embeddings,
#      84         metadatas=metadatas,
#      85         documents=documents,
#      86         images=images,
#      87         uris=uris,
#      88     )
#      90     self._client._add(
#      91         collection_id=self.id,
#      92         ids=add_request["ids"],
#    (...)
#      98         database=self.database,
#      99     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:93, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      91 except Exception as e:
#      92     msg = f"{str(e)} in {name}."
# ---> 93     raise type(e)(msg).with_traceback(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      87 @functools.wraps(func)
#      88 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      89     try:
# ---> 90         return func(self, *args, **kwargs)
#      91     except Exception as e:
#      92         msg = f"{str(e)} in {name}."
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:213, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     211 if add_records["embeddings"] is None:
#     212     validate_record_set_for_embedding(record_set=add_records)
# --> 213     add_embeddings = self._embed_record_set(record_set=add_records)
#     214 else:
#     215     add_embeddings = add_records["embeddings"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:526, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields)
#     522             return self._embed(
#     523                 input=self._data_loader(uris=cast(URIs, record_set[field]))  # type: ignore[literal-required]
#     524             )
#     525         else:
# --> 526             return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     527 raise ValueError(
#     528     "Record does not contain any non-None fields that can be embedded."
#     529     f"Embeddable Fields: {embeddable_fields}"
#     530     f"Record Fields: {record_set}"
#     531 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\models\CollectionCommon.py:539, in CollectionCommon._embed(self, input)
#     534 if self._embedding_function is None:
#     535     raise ValueError(
#     536         "You must provide an embedding function to compute embeddings."
#     537         "https://docs.trychroma.com/guides/embeddings"
#     538     )
# --> 539 return self._embedding_function(input=input)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\api\types.py:460, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     459 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 460     result = call(self, input)
#     461     assert result is not None
#     462     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:199, in ONNXMiniLM_L6_V2.__call__(self, input)
#     197 def __call__(self, input: Documents) -> Embeddings:
#     198     # Only download the model when it is actually used
# --> 199     self._download_model_if_not_exists()
#     200     return cast(Embeddings, self._forward(input))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:234, in ONNXMiniLM_L6_V2._download_model_if_not_exists(self)
#     226     self._download(
#     227         url=self.MODEL_DOWNLOAD_URL,
#     228         fname=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     229     )
#     230 with tarfile.open(
#     231     name=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     232     mode="r:gz",
#     233 ) as tar:
# --> 234     tar.extractall(path=self.DOWNLOAD_PATH)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2302, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2297     if tarinfo.isdir():
#    2298         # For directories, delay setting attributes until later,
#    2299         # since permissions can interfere with extraction and
#    2300         # extracting contents can reset mtime.
#    2301         directories.append(tarinfo)
# -> 2302     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2303                       numeric_owner=numeric_owner)
#    2305 # Reverse sort directories.
#    2306 directories.sort(key=lambda a: a.name, reverse=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2369, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2365     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2366                          set_attrs=set_attrs,
#    2367                          numeric_owner=numeric_owner)
#    2368 except OSError as e:
# -> 2369     self._handle_fatal_error(e)
#    2370 except ExtractError as e:
#    2371     self._handle_nonfatal_error(e)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2365, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2362 self._check("r")
#    2364 try:
# -> 2365     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2366                          set_attrs=set_attrs,
#    2367                          numeric_owner=numeric_owner)
#    2368 except OSError as e:
#    2369     self._handle_fatal_error(e)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2448, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner)
#    2445     self._dbg(1, tarinfo.name)
#    2447 if tarinfo.isreg():
# -> 2448     self.makefile(tarinfo, targetpath)
#    2449 elif tarinfo.isdir():
#    2450     self.makedir(tarinfo, targetpath)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2494, in TarFile.makefile(self, tarinfo, targetpath)
#    2492 source.seek(tarinfo.offset_data)
#    2493 bufsize = self.copybufsize
# -> 2494 with bltn_open(targetpath, "wb") as target:
#    2495     if tarinfo.sparse is not None:
#    2496         for offset, size in tarinfo.sparse:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\ideapad\\.cache\\chroma\\onnx_models\\all-MiniLM-L6-v2\\onnx\\tokenizer_config.json' in add.

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links

# %%
job

# %%
job = json_res
job['skills']

# %%
prompt_extract = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Krishna , a business executive at XYZ. XYZ is an AI & Software Based company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of XYZ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Krishna, BE at XYZ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in d:\gen_project\gen_ai\lib\site-packages (0.2.12)
# Requirement already satisfied: PyYAML>=5.3 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.13 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (0.2.14)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (0.1.140)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in d:\gen_project\gen_ai\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\gen_project\gen_ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\gen_project\gen_ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\gen_project\gen_ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\gen_project\gen_ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\gen_project\gen_ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in d:\gen_project\gen_ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\gen_project\gen_ai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\gen_project\gen_ai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in d:\gen_project\gen_ai\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain-community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in d:\gen_project\gen_ai\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\gen_project\gen_ai\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\gen_project\gen_ai\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in d:\gen_project\gen_ai\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\gen_project\gen_ai\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\gen_project\gen_ai\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\gen_project\gen_ai\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\gen_project\gen_ai\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\gen_project\gen_ai\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen_project\gen_ai\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\gen_project\gen_ai\lib\site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in d:\gen_project\gen_ai\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in d:\gen_project\gen_ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in d:\gen_project\gen_ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in d:\gen_project\gen_ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\gen_project\gen_ai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen_project\gen_ai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen_project\gen_ai\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\gen_project\gen_ai\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\gen_project\gen_ai\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\gen_project\gen_ai\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
